# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
wine = pd.read_csv("WineQT.csv")
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4

# %%
wine = wine.drop(['Id'],axis=1)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
wine['quality'].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing Data

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %%
wine.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# ## Corelation Matrix

# %%
corr = wine.corr()

# %%
plt.figure(figsize=(12,7))
sns.heatmap(corr,cmap="coolwarm",annot=True)
plt.show()

# %% [markdown]
# ## Model Training and Testing

# %%
from sklearn.model_selection import train_test_split
X = wine.drop(['quality'],axis=1)
Y = wine['quality']
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.30)

# %%
y_train
# Out:
# 221     6
# 1135    6
# 832     4
# 553     5
# 541     5
#        ..
# 983     5
# 203     5
# 1139    6
# 147     5
# 1140    5
# Name: quality, Length: 800, dtype: int64

# %% [markdown]
# ## Linear Regression

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
print('Linear Regression Accuracy: ',model.score(x_test,y_test)*100)
# Out:
# Linear Regression Accuracy:  30.551383852566648

# %%
#Model Training
model.fit(x_train.values,y_train.values)
# Out:
# LinearRegression()

# %%
#Print Metric to get the performance
print('Accuracy: ',model.score(x_test,y_test)*100)
# Out:
# Accuracy:  30.551383852566648

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([6.29086725, 5.70108864, 5.55341349, 6.1936453 , 5.12517837,
#        5.54963123, 5.11457678, 4.82348918, 6.30267072, 5.14254055,
#        5.28719698, 5.36948257, 4.67840974, 6.56799246, 5.08275141,
#        5.30423337, 5.80448103, 5.64134874, 5.71620052, 5.41114144,
#        5.32636832, 6.35007718, 5.64170043, 4.7055579 , 5.53338883,
#        5.33165758, 5.71026105, 5.0353    , 5.17705517, 5.04065271,
#        5.52954443, 5.74598548, 4.95775113, 6.12029383, 5.46343033,
#        5.7073598 , 5.62452726, 5.26737183, 6.38414892, 5.70465207,
#        5.75070678, 5.78699275, 5.93154455, 5.4168028 , 5.84594404,
#        5.5333439 , 6.1177479 , 5.91676349, 5.534779  , 6.62928802,
#        5.02031833, 4.82115632, 5.93295248, 5.63959759, 4.73430176,
#        6.53615902, 5.37751198, 5.97778918, 6.71739286, 5.35955899,
#        6.33253637, 5.3522452 , 5.5205871 , 4.80705808, 5.40488087,
#        5.23898056, 5.66034169, 5.72461462, 4.76679338, 6.65081394,
#        5.00577378, 5.7447047 , 6.20527881, 5.57447071, 4.9127175 ,
#        5.00817542, 6.43860131, 5.98218089, 5.32343928, 5.88380689,
#        5.51067143, 5.46642445, 5.79843268, 6.41275618, 5.63476169,
#        5.36166381, 4.92822342, 5.81496113, 4.93561504, 6.14140255,
#        5.19939315, 5.30180567, 5.3795475 , 6.18268496, 6.17671183,
#        5.42434821, 5.99084432, 5.32389965, 5.85268918, 5.8907096 ,
#        5.4478722 , 5.41070618, 5.3785785 , 6.14322339, 4.97647792,
#        4.78816634, 5.15942642, 6.28450852, 5.41998446, 6.01257256,
#        5.81453139, 6.06858481, 6.30318915, 5.47411475, 4.99163939,
#        5.79467693, 5.17389424, 5.74099304, 5.35200662, 6.07736531,
#        5.64183099, 5.7447047 , 5.15718191, 6.29086725, 5.19701198,
#        5.51633985, 5.94423099, 5.10270405, 5.70574689, 6.19090203,
#        4.89235706, 4.17517561, 6.14219792, 5.11861098, 5.53948577,
#        5.78440518, 6.26770581, 6.18850553, 5.36654021, 5.2510153 ,
#        6.45200533, 5.00447282, 5.49592038, 5.13802561, 5.72184465,
#        6.38461026, 5.10503554, 6.16322888, 5.59984513, 6.2078181 ,
#        5.82190252, 5.09127563, 4.91281004, 5.19174139, 4.97752656,
#        6.03658722, 5.68843336, 5.41372044])

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import r2_score,mean_absolute_error
score = r2_score(y_test,y_predict)
mae = mean_absolute_error(y_test,y_predict)

# %%
score
# Out:
# 0.3055138385256665

# %%
mae
# Out:
# 0.5163810300650047

# %% [markdown]
# ## Saving the File

# %%
import pickle
filename = 'Wine_Quality.sav'
pickle.dump(model,open(filename,'wb'))

# %%
load_model = pickle.load(open(filename,'rb'))

# %%
x_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 192            11.5             0.180         0.51             4.0      0.104
# 1003            6.4             0.470         0.40             2.4      0.071
# 734             7.6             0.780         0.00             1.7      0.076
# 834             8.2             0.350         0.33             2.4      0.076
# 1055            7.1             0.875         0.05             5.7      0.082
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 192                   4.0                  23.0  0.99960  3.28       0.97
# 1003                  8.0                  19.0  0.99630  3.56       0.73
# 734                  33.0                  45.0  0.99612  3.31       0.62
# 834                  11.0                  47.0  0.99599  3.27       0.81
# 1055                  3.0                  14.0  0.99808  3.40       0.52
#
#       alcohol
# 192      10.1
# 1003     10.6
# 734      10.7
# 834      11.0
# 1055     10.2

# %%
load_model.predict([[11.5,0.180,0.51,4.0,0.104,4.0,23.0,0.99960,3.28,0.97,10.1]])
# Out:
# array([6.29086725])
